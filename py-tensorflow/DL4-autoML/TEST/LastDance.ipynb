# %% [markdown]
# <a href="https://colab.research.google.com/github/seokmin1/PDM08/blob/main/py-tensorflow/DL4-autoML/TEST/LastDance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <<<<<>>>>>

# %%
# from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.applications.mobilenet_v2 import  MobileNetV2, preprocess_input
import tensorflow.keras as keras
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from keras.utils import np_utils
from keras.models import load_model
from keras.datasets import cifar10
from keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# import cv2
print(tf.__version__)
# Out:
# 2.7.0

# %%
tf.keras.backend.clear_session()  # For memory

# GPU check
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print("#### ", len(gpus), "Physical GPUs,",
                 len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
else:
    print('#### No CUDA supported GPU in this computer.')
# Out:
# ####  1 Physical GPUs, 1 Logical GPUs

# %%
from keras.datasets import cifar10
# load dataset
(trainX, trainy), (testX, testy) = cifar10.load_data()
# summarize loaded dataset
#print('Train: X=%s, y=%s' % (trainX.shape, trainy.shape))
#print('Test: X=%s, y=%s' % (testX.shape, testy.shape))

# %% [markdown]
# ---

# %%
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import os
# Matplotlib config
# plt.rc('image', cmap='gray')
plt.rc('grid', linewidth=0)
plt.rc('xtick', top=False, bottom=False, labelsize='large')
plt.rc('ytick', left=False, right=False, labelsize='large')
plt.rc('axes', facecolor='F8F8F8', titlesize="large", edgecolor='white')
plt.rc('text', color='000000')
plt.rc('figure', facecolor='F0F0F0')# Matplotlib fonts
MATPLOTLIB_FONT_DIR = os.path.join(os.path.dirname(plt.__file__), "mpl-data/fonts/ttf")

# utility to display a row of digits with their predictions
def display_images(digits, predictions, labels, title):

  n = 10

  indexes = np.random.choice(len(predictions), size=n)
  n_digits = digits[indexes]
  n_predictions = predictions[indexes]
  n_predictions = n_predictions.reshape((n,))
  n_labels = labels[indexes]
 
  fig = plt.figure(figsize=(20, 4))
  plt.title(title)
  plt.yticks([])
  plt.xticks([])

  for i in range(10):
    ax = fig.add_subplot(1, 10, i+1)
    class_index = n_predictions[i]
    true_index = n_labels[i]
    # Set x-label color: green if prediction correct and red if prediction incorrect
    plt.xlabel(classes[class_index])
    xlabel_color = "green" if n_predictions[i] == n_labels[i] else "red"
    ax.xaxis.label.set_color(xlabel_color) 
    plt.xticks([])
    plt.yticks([])
    plt.imshow(n_digits[i])

# %%
display_images(trainX, trainy, trainy, "Training Data" )

# %%
display_images(testX, testy, testy, "Validation Data" )

# %%
def preprocess_image_input(input_images):
  input_images = input_images.astype('float32')
  output_ims = preprocess_input(input_images)
  return output_ims

# %%
x_train = preprocess_image_input(trainX)
x_test = preprocess_image_input(testX)

# %%
x_train.shape,len(x_train),x_train[4].shape
# Out:
# ((50000, 32, 32, 3), 50000, (32, 32, 3))

# %%
y_train=trainy
y_test=testy
y_train.shape,y_test.shape
# Out:
# ((50000, 1), (10000, 1))

# %%
'''
Feature Extraction is performed by MobileNetV2 pretrained on imagenet weights. 
Input size is 224 x 224.
'''
def feature_extractor(inputs):

  TL_base = MobileNetV2(input_shape=(224, 224, 3),
                                               include_top=False,
                                               weights='imagenet')
  #   Unfreeze top layers for fine tuning
  TL_base.trainable = False
  return TL_base(inputs)


'''
Defines final dense layers and subsequent softmax layer for classification.
'''
def classifier(inputs):
    x = tf.keras.layers.GlobalAveragePooling2D()(inputs)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(1024, activation="relu")(x)
    x = tf.keras.layers.Dense(512, activation="relu")(x)
    x = tf.keras.layers.Dense(10, activation="softmax", name="classification")(x)
    return x

'''
Since input image size is (32 x 32), first upsample the image by factor of (7x7) to transform it to (224 x 224)
Connect the feature extraction and "classifier" layers to build the model.
'''
def final_model(inputs):

    resize = tf.keras.layers.UpSampling2D(size=(7,7))(inputs)

    resnet_feature_extractor = feature_extractor(resize)
    classification_output = classifier(resnet_feature_extractor)

    return classification_output

'''
Define the model and compile it. 
Use Stochastic Gradient Descent as the optimizer.
Use Sparse Categorical CrossEntropy as the loss function.
'''
def define_compile_model():
  inputs = tf.keras.layers.Input(shape=(32,32,3))
  
  classification_output = final_model(inputs) 
  model = tf.keras.Model(inputs=inputs, outputs = classification_output)
 
  model.compile(optimizer='SGD', 
                loss='sparse_categorical_crossentropy',  # y_train is NOT one-hot encoded!
                metrics = ['accuracy'])
  
  return model


model = define_compile_model()

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  up_sampling2d (UpSampling2D  (None, 224, 224, 3)      0
#  )
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 1280)              0
#
#  dense (Dense)               (None, 1024)              1311744
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  classification (Dense)      (None, 10)                5130
#
# =================================================================
# Total params: 4,099,658
# Trainable params: 1,841,674
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
# Plot model
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True, to_file='model_F.png')

# %%
from tensorflow.keras import layers, models, callbacks

# %%
mc_callback = callbacks.ModelCheckpoint(filepath="./model/cifar10pct100_mobileNetV2F_SGD_best_weights.{epoch:03d}-{val_accuracy:.3f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=5)

# %%
# %%time
EPOCHS = 100
BATCH_SIZE = 50  # 32, 50, 64, 100
history = model.fit(x_train, y_train, 
                    epochs=EPOCHS, 
                    validation_data = (x_test, y_test), 
                    batch_size=BATCH_SIZE,
                    callbacks=[mc_callback,es_callback])
# Out:
# Epoch 1/100
# 1000/1000 [==============================] - ETA: 0s - loss: 1.1038 - accuracy: 0.6167
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# 1000/1000 [==============================] - 191s 192ms/step - loss: 1.1038 - accuracy: 0.6167 - val_loss: 0.9123 - val_accuracy: 0.6782
# Epoch 2/100
# 1000/1000 [==============================] - 177s 177ms/step - loss: 0.8610 - accuracy: 0.6980 - val_loss: 0.9119 - val_accuracy: 0.6759
# Epoch 3/100
# 1000/1000 [==============================] - 190s 190ms/step - loss: 0.7925 - accuracy: 0.7246 - val_loss: 0.8309 - val_accuracy: 0.7060
# Epoch 4/100
# 1000/1000 [==============================] - 190s 190ms/step - loss: 0.7490 - accuracy: 0.7389 - val_loss: 0.7687 - val_accuracy: 0.7317
# Epoch 5/100
# 1000/1000 [==============================] - 190s 190ms/step - loss: 0.7126 - accuracy: 0.7491 - val_loss: 0.7794 - val_accuracy: 0.7239
# Epoch 6/100
# 1000/1000 [==============================] - 190s 190ms/step - loss: 0.6834 - accuracy: 0.7612 - val_loss: 0.7576 - val_accuracy: 0.7274
# Epoch 7/100
# 1000/1000 [==============================] - 190s 190ms/step - loss: 0.6568 - accuracy: 0.7683 - val_loss: 0.7590 - val_accuracy: 0.7333
# Epoch 8/100
# 1000/1000 [==============================] - 177s 177ms/step - loss: 0.6338 - accuracy: 0.7796 - val_loss: 0.7107 - val_accuracy: 0.7522
# Epoch 9/100
# 1000/1000 [==============================] - 178s 178ms/step - loss: 0.6115 - accuracy: 0.7857 - val_loss: 0.6982 - val_accuracy: 0.7579
# Epoch 10/100
# 1000/1000 [==============================] - 190s 190ms/step - loss: 0.5907 - accuracy: 0.7936 - val_loss: 0.7037 - val_accuracy: 0.7531
# Epoch 11/100
# 1000/1000 [==============================] - 176s 177ms/step - loss: 0.5704 - accuracy: 0.8013 - val_loss: 0.7087 - val_accuracy: 0.7566
# Epoch 12/100
# 1000/1000 [==============================] - 190s 190ms/step - loss: 0.5522 - accuracy: 0.8076 - val_loss: 0.7100 - val_accuracy: 0.7551
# Epoch 13/100
# 1000/1000 [==============================] - 190s 190ms/step - loss: 0.5325 - accuracy: 0.8148 - val_loss: 0.6923 - val_accuracy: 0.7595
# Epoch 14/100
# 1000/1000 [==============================] - 177s 177ms/step - loss: 0.5146 - accuracy: 0.8222 - val_loss: 0.6975 - val_accuracy: 0.7598
# Epoch 15/100
# 1000/1000 [==============================] - 190s 190ms/step - loss: 0.4957 - accuracy: 0.8269 - val_loss: 0.6669 - val_accuracy: 0.7694
# Epoch 16/100
# 1000/1000 [==============================] - 176s 176ms/step - loss: 0.4800 - accuracy: 0.8328 - val_loss: 0.7217 - val_accuracy: 0.7517
# Epoch 17/100
# 1000/1000 [==============================] - 176s 176ms/step - loss: 0.4618 - accuracy: 0.8411 - val_loss: 0.6784 - val_accuracy: 0.7681
# Epoch 18/100
# 1000/1000 [==============================] - 190s 190ms/step - loss: 0.4460 - accuracy: 0.8462 - val_loss: 0.6944 - val_accuracy: 0.7626
# Epoch 19/100
# 1000/1000 [==============================] - 190s 190ms/step - loss: 0.4316 - accuracy: 0.8515 - val_loss: 0.6964 - val_accuracy: 0.7648
# Epoch 20/100
# 1000/1000 [==============================] - 177s 177ms/step - loss: 0.4150 - accuracy: 0.8565 - val_loss: 0.6668 - val_accuracy: 0.7715
# Epoch 21/100
# 1000/1000 [==============================] - 190s 190ms/step - loss: 0.3964 - accuracy: 0.8632 - val_loss: 0.6977 - val_accuracy: 0.7700
# Epoch 22/100
# 1000/1000 [==============================] - 190s 190ms/step - loss: 0.3832 - accuracy: 0.8690 - val_loss: 0.6810 - val_accuracy: 0.7716
# Epoch 23/100
# 1000/1000 [==============================] - 190s 190ms/step - loss: 0.3680 - accuracy: 0.8729 - val_loss: 0.6862 - val_accuracy: 0.7679
# Epoch 24/100
# 1000/1000 [==============================] - 177s 177ms/step - loss: 0.3511 - accuracy: 0.8809 - val_loss: 0.7023 - val_accuracy: 0.7684
# Epoch 25/100
# 1000/1000 [==============================] - 190s 190ms/step - loss: 0.3387 - accuracy: 0.8864 - val_loss: 0.6827 - val_accuracy: 0.7730
# Epoch 26/100
# 1000/1000 [==============================] - 177s 177ms/step - loss: 0.3251 - accuracy: 0.8889 - val_loss: 0.7216 - val_accuracy: 0.7605
# Epoch 27/100
# 1000/1000 [==============================] - 190s 190ms/step - loss: 0.3111 - accuracy: 0.8953 - val_loss: 0.6986 - val_accuracy: 0.7705
# Epoch 28/100
# 1000/1000 [==============================] - 190s 190ms/step - loss: 0.2955 - accuracy: 0.9021 - val_loss: 0.7094 - val_accuracy: 0.7694
# Epoch 29/100
# 1000/1000 [==============================] - 177s 177ms/step - loss: 0.2829 - accuracy: 0.9047 - val_loss: 0.7651 - val_accuracy: 0.7591
# Epoch 30/100
# 1000/1000 [==============================] - 177s 177ms/step - loss: 0.2686 - accuracy: 0.9106 - val_loss: 0.7379 - val_accuracy: 0.7671
# Epoch 00030: early stopping
# CPU times: user 1h 27min 57s, sys: 44.6 s, total: 1h 28min 41s
# Wall time: 1h 32min 21s

# %%
model.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
# Out:
# 200/200 [==============================] - 29s 146ms/step - loss: 0.7379 - accuracy: 0.7671
# [0.7378957867622375, 0.7670999765396118]

# %%
# 훈련 데이터와 검증 데이터에 대한 loss 시각화.
epochs = range(1, len(history.history['loss']) + 1)

loss_list = history.history['loss'] #[100 * i for i in history.history['loss']]
vloss_list = history.history['val_loss'] #[100 * i for i in history.history['val_loss']]

plt.plot(epochs,loss_list)  
plt.plot(epochs,vloss_list)

plt.plot(np.argmin(np.array(vloss_list))+1,vloss_list[np.argmin(np.array(vloss_list))], 'r*')
plt.title('cifar10_100%: TL(mobilenetV2) Sequential model - val_loss, min:' + str(np.round(vloss_list[np.argmin(np.array(vloss_list))],2)))
plt.ylabel('val-Loss (%)')
plt.xlabel('Epoch')
plt.legend(['loss','val_loss','best'], loc='best')
plt.show()

# %%
# 훈련 데이터와 검증 데이터에 대한 accuracy 시각화.
epochs = range(1, len(history.history['accuracy']) + 1)

acc_list = [100 * i for i in history.history['accuracy']]
vacc_list = [100 * i for i in history.history['val_accuracy']]

plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)

plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*')
plt.title('cifar10_100%: TL(mobilenetV2) Sequential model - val_accuracy, max:' + str(np.round(vacc_list[np.argmax(np.array(vacc_list))],2)))
plt.ylabel('val-Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy','best'], loc='best')
plt.show()

# %%
# More graphs of loss and accuracy
history_dict = history.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],3)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],3)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
probabilities = model.predict(x_test, batch_size=BATCH_SIZE)
probabilities = np.argmax(probabilities, axis = 1)

display_images(testX, probabilities, testy, "Predictions of the validation data")

# %% [markdown]
# ---

# %%
tf.keras.backend.clear_session()  # For memory

# %%
'''
Feature Extraction is performed by MobileNetV2 pretrained on imagenet weights. 
Input size is 224 x 224.
'''
def feature_extractor_fine_tuning(inputs):

  TL_base = MobileNetV2(input_shape=(224, 224, 3),
                            include_top=False,
                            weights='imagenet')
#   Unfreeze top layers for fine tuning
  TL_base.trainable = True
  # Fine-tune from this layer onwards
  fine_tune_at = 107

  # Freeze all the layers before the `fine_tune_at` layer
  for layer in TL_base.layers[:fine_tune_at]:
    layer.trainable =  False

  return TL_base(inputs)

def final_model_ft(inputs):

    resize = tf.keras.layers.UpSampling2D(size=(7,7))(inputs)

    fine_feature_extractor = feature_extractor_fine_tuning(resize)
    classification_output = classifier(fine_feature_extractor)

    return classification_output

def define_compile_model_ft():
  inputs = tf.keras.layers.Input(shape=(32,32,3))
  
  classification_output = final_model_ft(inputs) 
  model = tf.keras.Model(inputs=inputs, outputs = classification_output)
 
  model.compile(optimizer='SGD', 
                loss='sparse_categorical_crossentropy',  # y_train is NOT one-hot encoded!
                metrics = ['accuracy'])
  
  return model

model = define_compile_model_ft()

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  up_sampling2d (UpSampling2D  (None, 224, 224, 3)      0
#  )
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 1280)              0
#
#  dense (Dense)               (None, 1024)              1311744
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  classification (Dense)      (None, 10)                5130
#
# =================================================================
# Total params: 4,099,658
# Trainable params: 3,641,290
# Non-trainable params: 458,368
# _________________________________________________________________

# %%
from tensorflow.keras import layers, models, callbacks

# %%
mc_callback = callbacks.ModelCheckpoint(filepath="./model/cifar10pct100_mobileNetV2F_SGD_FT_best_weights.{epoch:03d}-{val_accuracy:.3f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=5)

# %%
INITIAL_EPOCHS = len(loss)
FINE_TUNE_EPOCHS = 100
TOTAL_EPOCHS = INITIAL_EPOCHS + FINE_TUNE_EPOCHS #

# %%
# %%time
BATCH_SIZE = 50  # 32, 50, 64, 100
history_fine = model.fit(x_train, y_train, 
                    epochs=TOTAL_EPOCHS, 
                    initial_epoch=INITIAL_EPOCHS,
                    validation_data = (x_test, y_test), 
                    batch_size=BATCH_SIZE,
                    callbacks=[mc_callback,es_callback])
# Out:
# Epoch 31/130
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6661 - accuracy: 0.7748
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# 1000/1000 [==============================] - 243s 239ms/step - loss: 0.6661 - accuracy: 0.7748 - val_loss: 1.0166 - val_accuracy: 0.6600
# Epoch 32/130
# 1000/1000 [==============================] - 251s 251ms/step - loss: 0.3105 - accuracy: 0.8940 - val_loss: 0.4746 - val_accuracy: 0.8417
# Epoch 33/130
# 1000/1000 [==============================] - 251s 251ms/step - loss: 0.1864 - accuracy: 0.9364 - val_loss: 0.4328 - val_accuracy: 0.8590
# Epoch 34/130
# 1000/1000 [==============================] - 250s 250ms/step - loss: 0.1137 - accuracy: 0.9621 - val_loss: 0.5215 - val_accuracy: 0.8506
# Epoch 35/130
# 1000/1000 [==============================] - 237s 237ms/step - loss: 0.0657 - accuracy: 0.9788 - val_loss: 0.4719 - val_accuracy: 0.8680
# Epoch 36/130
# 1000/1000 [==============================] - 251s 251ms/step - loss: 0.0414 - accuracy: 0.9874 - val_loss: 0.4752 - val_accuracy: 0.8774
# Epoch 37/130
# 1000/1000 [==============================] - 250s 250ms/step - loss: 0.0298 - accuracy: 0.9907 - val_loss: 0.4838 - val_accuracy: 0.8779
# Epoch 38/130
# 1000/1000 [==============================] - 237s 237ms/step - loss: 0.0238 - accuracy: 0.9930 - val_loss: 0.5470 - val_accuracy: 0.8751
# Epoch 39/130
# 1000/1000 [==============================] - 251s 251ms/step - loss: 0.0184 - accuracy: 0.9942 - val_loss: 0.5450 - val_accuracy: 0.8786
# Epoch 40/130
# 1000/1000 [==============================] - 237s 237ms/step - loss: 0.0152 - accuracy: 0.9953 - val_loss: 0.5535 - val_accuracy: 0.8843
# Epoch 41/130
# 1000/1000 [==============================] - 250s 250ms/step - loss: 0.0125 - accuracy: 0.9964 - val_loss: 0.5256 - val_accuracy: 0.8850
# Epoch 42/130
# 1000/1000 [==============================] - 237s 237ms/step - loss: 0.0087 - accuracy: 0.9974 - val_loss: 0.5584 - val_accuracy: 0.8887
# Epoch 43/130
# 1000/1000 [==============================] - 237s 237ms/step - loss: 0.0112 - accuracy: 0.9965 - val_loss: 0.5517 - val_accuracy: 0.8893
# Epoch 44/130
# 1000/1000 [==============================] - 237s 237ms/step - loss: 0.0104 - accuracy: 0.9966 - val_loss: 0.5691 - val_accuracy: 0.8911
# Epoch 45/130
# 1000/1000 [==============================] - 237s 237ms/step - loss: 0.0102 - accuracy: 0.9969 - val_loss: 0.6366 - val_accuracy: 0.8763
# Epoch 46/130
# 1000/1000 [==============================] - 251s 251ms/step - loss: 0.0082 - accuracy: 0.9975 - val_loss: 0.5873 - val_accuracy: 0.8865
# Epoch 47/130
# 1000/1000 [==============================] - 238s 238ms/step - loss: 0.0077 - accuracy: 0.9977 - val_loss: 0.6273 - val_accuracy: 0.8792
# Epoch 48/130
# 1000/1000 [==============================] - 238s 238ms/step - loss: 0.0091 - accuracy: 0.9972 - val_loss: 0.6323 - val_accuracy: 0.8845
# Epoch 49/130
# 1000/1000 [==============================] - 238s 238ms/step - loss: 0.0069 - accuracy: 0.9979 - val_loss: 0.6796 - val_accuracy: 0.8797
# Epoch 00049: early stopping
# CPU times: user 1h 14min 57s, sys: 31.7 s, total: 1h 15min 29s
# Wall time: 1h 17min

# %%
model.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
# Out:
# 200/200 [==============================] - 29s 146ms/step - loss: 0.6796 - accuracy: 0.8797
# [0.6796064376831055, 0.8797000050544739]

# %%
# Display training curve

acc = history.history['accuracy'] + history_fine.history['accuracy']
val_acc = history.history['val_accuracy'] + history_fine.history['val_accuracy']

plt.figure(figsize=(8, 4))

plt.plot(acc, label='Train accuracy')
plt.plot(val_acc, label='Val accuracy')
# plt.ylim([0.8, 1])
plt.plot([INITIAL_EPOCHS-1, INITIAL_EPOCHS-1], plt.ylim(ymin=acc[0]), label='Start Fine Tuning')
plt.title("Fine-tune a Pretrained ConvNet:MobileNetV2-F")
plt.legend(loc='upper left')

plt.show()

# %%
# More graphs of loss and accuracy in Fine Tuning
history_dict = history_fine.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(INITIAL_EPOCHS, INITIAL_EPOCHS+len(loss))

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(INITIAL_EPOCHS + np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],3)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

# epochs = range(1, len(loss_values) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy')#, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(INITIAL_EPOCHS + np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Fine Tuning: Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],3)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
## cifar10pct100_mobileNetV2F_SGD_best_weights.025-0.773.hdf5

from keras.models import load_model

# returns a compiled model
# identical to the previous one
model = load_model('./model/cifar10pct100_mobileNetV2F_SGD_best_weights.025-0.773.hdf5')
model.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
# Out:
# 200/200 [==============================] - 30s 146ms/step - loss: 0.6827 - accuracy: 0.7730
# [0.6826632022857666, 0.7730000019073486]

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
predictions = model.predict(testX)
predictions0 = np.argmax(predictions, axis=1)
cm = confusion_matrix(testy, predictions0)
plt.figure(figsize=(9,9))
sns.heatmap(cm, cbar=False, xticklabels=classes, yticklabels=classes, fmt='d', annot=True, cmap=plt.cm.coolwarm)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion matrix', fontsize=20)
plt.show()
